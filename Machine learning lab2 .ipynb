# %%
# TASK A

import pandas as pd
# to display excel sheet import pandas
df=pd.read_excel('Book1.xlsx')
#to find first 5 rows in datas
df.head()
# Out:
#    RollNo   Name  Attendace  Internal Marks  External marks Gender
# 0     101   Ravi         85              32              55      M
# 1     102  Priya         92              38              58      F
# 2     103  Kiran         78              28              45      M
# 3     104    Anu         95              40              60      F
# 4     105   Sita         88              35              54      F

# %%
# to find last 5 rows in dataset
df.tail()
# Out:
#    RollNo     Name  Attendace  Internal Marks  External marks Gender
# 5     106      Raj         70              25              40      M
# 6     107    Divya         90              37              57      F
# 7     108     Arun         82              30              48      M
# 8     109  Keerthi         96              39              59      F
# 9     110   Naveen         75              27              44      M

# %%
# to find total no rows and colums
df.shape
# Out:
# (10, 6)

# %%
#display all colums names
df.columns
# Out:
# Index(['RollNo', 'Name', 'Attendace', 'Internal Marks', 'External marks',
#        'Gender'],
#       dtype='object')

# %%
#display data type of each and every colum
df.dtypes
# Out:
# RollNo             int64
# Name              object
# Attendace          int64
# Internal Marks     int64
# External marks     int64
# Gender            object
# dtype: object

# %%
#get dataset information using info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   RollNo          10 non-null     int64
#  1   Name            10 non-null     object
#  2   Attendace       10 non-null     int64
#  3   Internal Marks  10 non-null     int64
#  4   External marks  10 non-null     int64
#  5   Gender          10 non-null     object
# dtypes: int64(4), object(2)
# memory usage: 612.0+ bytes

# %%
#TASK B
#CALCULATE THE MEAN ATTENDANCE OF ALL STUDENTS
print("mean:",df['Attendace'].mean())
# Out:
# mean: 85.1

# %%
#CALCULATE AVERAGE INTERNAL MARKS
print("Average of internal marks:",df['Internal Marks'].mean())
# Out:
# Average of internal marks: 33.1

# %%
#CALCULATE AVERAGE EXTERNAL MARKS
print("Average of external marks:",df['External marks'].mean())
# Out:
# Average of external marks: 52.0

# %%
#CALCULATE MAX INTERNAL MARKS
df['Internal Marks'].max()
# Out:
# np.int64(40)

# %%
#CALCULATE MIN INTERNAL MARKS
df['Internal Marks'].min()
# Out:
# np.int64(25)

# %%
#CALCULATE MAX EXTERNAL MARKS
df['External marks'].max()
# Out:
# np.int64(60)

# %%
#CALCULATE MIN EXTERNAL MARKS
df['External marks'].min()
# Out:
# np.int64(40)

# %%
#calculate standard deviation of internal marks
df['Internal Marks'].std()
# Out:
# np.float64(5.425249610233001)

# %%
#generate summary statistics using decribe
res=df.describe()
print(res)
# Out:
#           RollNo  Attendace  Internal Marks  External marks
# count   10.00000  10.000000        10.00000       10.000000
# mean   105.50000  85.100000        33.10000       52.000000
# std      3.02765   8.736259         5.42525        7.149204
# min    101.00000  70.000000        25.00000       40.000000
# 25%    103.25000  79.000000        28.50000       45.750000
# 50%    105.50000  86.500000        33.50000       54.500000
# 75%    107.75000  91.500000        37.75000       57.750000
# max    110.00000  96.000000        40.00000       60.000000

# %%
#TASK C
#make total marks column poercentage columan and display the updated dataset
df['total marks']=df['Internal Marks']+df['External marks']
df['percentage']=df['total marks']/ (100*100)
display(df)
# Out:
#    RollNo     Name  Attendace  Internal Marks  External marks Gender  \
# 0     101     Ravi         85              32              55      M
# 1     102    Priya         92              38              58      F
# 2     103    Kiran         78              28              45      M
# 3     104      Anu         95              40              60      F
# 4     105     Sita         88              35              54      F
# 5     106      Raj         70              25              40      M
# 6     107    Divya         90              37              57      F
# 7     108     Arun         82              30              48      M
# 8     109  Keerthi         96              39              59      F
# 9     110   Naveen         75              27              44      M
#
#    total marks  percentage
# 0           87      0.0087
# 1           96      0.0096
# 2           73      0.0073
# 3          100      0.0100
# 4           89      0.0089
# 5           65      0.0065
# ...

# %%
#TASK D

df[df['Attendace']>90]
# Out:
#    RollNo     Name  Attendace  Internal Marks  External marks Gender  \
# 1     102    Priya         92              38              58      F
# 3     104      Anu         95              40              60      F
# 8     109  Keerthi         96              39              59      F
#
#    total marks  percentage
# 1           96      0.0096
# 3          100      0.0100
# 8           98      0.0098

# %%
df[df['total marks']>90]
# Out:
#    RollNo     Name  Attendace  Internal Marks  External marks Gender  \
# 1     102    Priya         92              38              58      F
# 3     104      Anu         95              40              60      F
# 6     107    Divya         90              37              57      F
# 8     109  Keerthi         96              39              59      F
#
#    total marks  percentage
# 1           96      0.0096
# 3          100      0.0100
# 6           94      0.0094
# 8           98      0.0098

# %%
df[df['Gender']=='F']
# Out:
#    RollNo     Name  Attendace  Internal Marks  External marks Gender  \
# 1     102    Priya         92              38              58      F
# 3     104      Anu         95              40              60      F
# 4     105     Sita         88              35              54      F
# 6     107    Divya         90              37              57      F
# 8     109  Keerthi         96              39              59      F
#
#    total marks  percentage
# 1           96      0.0096
# 3          100      0.0100
# 4           89      0.0089
# 6           94      0.0094
# 8           98      0.0098

# %%
df[df['Gender']=='M']
# Out:
#    RollNo    Name  Attendace  Internal Marks  External marks Gender  \
# 0     101    Ravi         85              32              55      M
# 2     103   Kiran         78              28              45      M
# 5     106     Raj         70              25              40      M
# 7     108    Arun         82              30              48      M
# 9     110  Naveen         75              27              44      M
#
#    total marks  percentage
# 0           87      0.0087
# 2           73      0.0073
# 5           65      0.0065
# 7           78      0.0078
# 9           71      0.0071

# %%
df[df['External marks']<50]
# Out:
#    RollNo    Name  Attendace  Internal Marks  External marks Gender  \
# 2     103   Kiran         78              28              45      M
# 5     106     Raj         70              25              40      M
# 7     108    Arun         82              30              48      M
# 9     110  Naveen         75              27              44      M
#
#    total marks  percentage
# 2           73      0.0073
# 5           65      0.0065
# 7           78      0.0078
# 9           71      0.0071

# %%
#TASK E
#Highest Total Marks Student
print(df[df['total marks']==df['total marks'].max()])
# Out:
#    RollNo Name  Attendace  Internal Marks  External marks Gender  total marks  \
# 3     104  Anu         95              40              60      F          100
#
#    percentage
# 3        0.01

# %%
#Lowest Total Marks Student
print(df[df['total marks']==df['total marks'].min()])
# Out:
#    RollNo Name  Attendace  Internal Marks  External marks Gender  total marks  \
# 5     106  Raj         70              25              40      M           65
#
#    percentage
# 5      0.0065

# %%
#Top 3 Performers
print(df.sort_values('total marks',ascending=False).head(3))
# Out:
#    RollNo     Name  Attendace  Internal Marks  External marks Gender  \
# 3     104      Anu         95              40              60      F
# 8     109  Keerthi         96              39              59      F
# 1     102    Priya         92              38              58      F
#
#    total marks  percentage
# 3          100      0.0100
# 8           98      0.0098
# 1           96      0.0096

# %%
#Bottom 3 Performers
print(df.sort_values('total marks').head(3))
# Out:
#    RollNo    Name  Attendace  Internal Marks  External marks Gender  \
# 5     106     Raj         70              25              40      M
# 9     110  Naveen         75              27              44      M
# 2     103   Kiran         78              28              45      M
#
#    total marks  percentage
# 5           65      0.0065
# 9           71      0.0071
# 2           73      0.0073

# %%
#Students Above Class Average
avg=df['total marks'].mean()
print((df['total marks']>avg).sum())
# Out:
# 6

# %%
#TASK F : Group-wise Analysis
#Average Total Marks of Male Students
print(df[df['Gender']=='M']['total marks'].mean())
# Out:
# 74.8

# %%
#Average Total Marks of Female Students
print(df[df['Gender']=='F']['total marks'].mean())
# Out:
# 95.4

# %%
#Average Attendance of Male Students
print(df[df['Gender']=='M']['Attendace'].mean())
# Out:
# 78.0

# %%
#Average Attendance of Female Students
print(df[df['Gender']=='F']['Attendace'].mean())
# Out:
# 92.2

# %%
#TASK G : Data Visualization
#Bar Chart
import matplotlib.pyplot as plt
plt.bar(df['Name'],df['total marks'])
plt.show()

# %%
#Histogram
plt.hist(df['Attendace'])
plt.show()

# %%
#Pie Chart
df['Gender'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %%
#Scatter Plot
plt.scatter(df['Attendace'],df['total marks'])
plt.show()

# %%
#Interpretation
print("Higher attendance students generally have higher marks.")
# Out:
# Higher attendance students generally have higher marks.

# %%
# TASK H : Observations
print("1. Anu scored the highest marks.")
print("2. Raj scored the lowest marks.")
print("3. Students with high attendance scored better.")
# Out:
# 1. Anu scored the highest marks.
# 2. Raj scored the lowest marks.
# 3. Students with high attendance scored better.

# %%
print("Yes, higher attendance is associated with better academic performance.")
# Out:
# Yes, higher attendance is associated with better academic performance.
